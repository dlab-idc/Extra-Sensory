# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from General import *
from ReadingTheDataUtils import *

# Make the notebook automatically reload external python modules
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pathlib import Path

ROOT_PATH = Path('..')
SRC_PATH = Path('.')
DATA_PATH = ROOT_PATH / 'data'
CSV_PATH = DATA_PATH / 'ExtraSensory.per_uuid_features_labels'
CSV_SUFFIX = '.features_labels.csv'
ORIGINAL_LABLES_CSV_PATH = DATA_PATH / 'ExtraSensory.per_uuid_original_labels'
ORIGINAL_LABLES_CSV_SUFFIX = '.original_labels.csv'
FOLD_PATH = DATA_PATH / 'cv_5_folds'

main_label_names = ['label:LYING_DOWN', 'label:SITTING', 'label:OR_standing', 'label:FIX_walking', 'label:FIX_running', 'label:BICYCLING']

# %% [markdown]
# ### Read the features data

# %%
# %%time
# Read all data
features_df = get_all_uuids(CSV_PATH)
# Out:
# Wall time: 12.4 s

# %%
label_names = get_label_names(features_df)
label_names
# Out:
# ['label:LYING_DOWN',
#  'label:SITTING',
#  'label:FIX_walking',
#  'label:FIX_running',
#  'label:BICYCLING',
#  'label:SLEEPING',
#  'label:LAB_WORK',
#  'label:IN_CLASS',
#  'label:IN_A_MEETING',
#  'label:LOC_main_workplace',
#  'label:OR_indoors',
#  'label:OR_outside',
#  'label:IN_A_CAR',
#  'label:ON_A_BUS',
#  'label:DRIVE_-_I_M_THE_DRIVER',
#  'label:DRIVE_-_I_M_A_PASSENGER',
#  'label:LOC_home',
#  'label:FIX_restaurant',
#  'label:PHONE_IN_POCKET',
#  'label:OR_exercise',
#  'label:COOKING',
#  'label:SHOPPING',
#  'label:STROLLING',
#  'label:DRINKING__ALCOHOL_',
#  'label:BATHING_-_SHOWER',
#  'label:CLEANING',
#  'label:DOING_LAUNDRY',
#  'label:WASHING_DISHES',
#  'label:WATCHING_TV',
#  'label:SURFING_THE_INTERNET',
#  'label:AT_A_PARTY',
#  'label:AT_A_BAR',
#  'label:LOC_beach',
#  'label:SINGING',
#  'label:TALKING',
#  'label:COMPUTER_WORK',
#  'label:EATING',
#  'label:TOILET',
#  'label:GROOMING',
#  'label:DRESSING',
#  'label:AT_THE_GYM',
#  'label:STAIRS_-_GOING_UP',
#  'label:STAIRS_-_GOING_DOWN',
#  'label:ELEVATOR',
#  'label:OR_standing',
#  'label:AT_SCHOOL',
#  'label:PHONE_IN_HAND',
#  'label:PHONE_IN_BAG',
#  'label:PHONE_ON_TABLE',
#  'label:WITH_CO-WORKERS',
#  'label:WITH_FRIENDS']

# %%
label_df = features_df[main_label_names + ['timestamp']]
features_df = features_df[get_feature_names(features_df, label_names) + ['timestamp']]

# %%
features_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 377346 entries, 00EABED2-271D-49D8-B599-1D4A09240601 to FDAA70A1-42A3-4E3F-9AE3-3FDA412E03BF
# Data columns (total 226 columns):
# raw_acc:magnitude_stats:mean                                               float64
# raw_acc:magnitude_stats:std                                                float64
# raw_acc:magnitude_stats:moment3                                            float64
# raw_acc:magnitude_stats:moment4                                            float64
# raw_acc:magnitude_stats:percentile25                                       float64
# raw_acc:magnitude_stats:percentile50                                       float64
# raw_acc:magnitude_stats:percentile75                                       float64
# raw_acc:magnitude_stats:value_entropy                                      float64
# raw_acc:magnitude_stats:time_entropy                                       float64
# raw_acc:magnitude_spectrum:log_energy_band0                                float64
# raw_acc:magnitude_spectrum:log_energy_band1                                float64
# raw_acc:magnitude_spectrum:log_energy_band2                                float64
# raw_acc:magnitude_spectrum:log_energy_band3                                float64
# raw_acc:magnitude_spectrum:log_energy_band4                                float64
# raw_acc:magnitude_spectrum:spectral_entropy                                float64
# raw_acc:magnitude_autocorrelation:period                                   float64
# raw_acc:magnitude_autocorrelation:normalized_ac                            float64
# raw_acc:3d:mean_x                                                          float64
# raw_acc:3d:mean_y                                                          float64
# raw_acc:3d:mean_z                                                          float64
# raw_acc:3d:std_x                                                           float64
# raw_acc:3d:std_y                                                           float64
# raw_acc:3d:std_z                                                           float64
# raw_acc:3d:ro_xy                                                           float64
# raw_acc:3d:ro_xz                                                           float64
# raw_acc:3d:ro_yz                                                           float64
# proc_gyro:magnitude_stats:mean                                             float64
# proc_gyro:magnitude_stats:std                                              float64
# proc_gyro:magnitude_stats:moment3                                          float64
# proc_gyro:magnitude_stats:moment4                                          float64
# proc_gyro:magnitude_stats:percentile25                                     float64
# proc_gyro:magnitude_stats:percentile50                                     float64
# proc_gyro:magnitude_stats:percentile75                                     float64
# proc_gyro:magnitude_stats:value_entropy                                    float64
# proc_gyro:magnitude_stats:time_entropy                                     float64
# proc_gyro:magnitude_spectrum:log_energy_band0                              float64
# proc_gyro:magnitude_spectrum:log_energy_band1                              float64
# proc_gyro:magnitude_spectrum:log_energy_band2                              float64
# proc_gyro:magnitude_spectrum:log_energy_band3                              float64
# proc_gyro:magnitude_spectrum:log_energy_band4                              float64
# proc_gyro:magnitude_spectrum:spectral_entropy                              float64
# proc_gyro:magnitude_autocorrelation:period                                 float64
# proc_gyro:magnitude_autocorrelation:normalized_ac                          float64
# proc_gyro:3d:mean_x                                                        float64
# proc_gyro:3d:mean_y                                                        float64
# proc_gyro:3d:mean_z                                                        float64
# proc_gyro:3d:std_x                                                         float64
# proc_gyro:3d:std_y                                                         float64
# proc_gyro:3d:std_z                                                         float64
# proc_gyro:3d:ro_xy                                                         float64
# proc_gyro:3d:ro_xz                                                         float64
# proc_gyro:3d:ro_yz                                                         float64
# raw_magnet:magnitude_stats:mean                                            float64
# raw_magnet:magnitude_stats:std                                             float64
# raw_magnet:magnitude_stats:moment3                                         float64
# raw_magnet:magnitude_stats:moment4                                         float64
# raw_magnet:magnitude_stats:percentile25                                    float64
# raw_magnet:magnitude_stats:percentile50                                    float64
# raw_magnet:magnitude_stats:percentile75                                    float64
# raw_magnet:magnitude_stats:value_entropy                                   float64
# raw_magnet:magnitude_stats:time_entropy                                    float64
# raw_magnet:magnitude_spectrum:log_energy_band0                             float64
# raw_magnet:magnitude_spectrum:log_energy_band1                             float64
# raw_magnet:magnitude_spectrum:log_energy_band2                             float64
# raw_magnet:magnitude_spectrum:log_energy_band3                             float64
# raw_magnet:magnitude_spectrum:log_energy_band4                             float64
# raw_magnet:magnitude_spectrum:spectral_entropy                             float64
# raw_magnet:magnitude_autocorrelation:period                                float64
# raw_magnet:magnitude_autocorrelation:normalized_ac                         float64
# raw_magnet:3d:mean_x                                                       float64
# raw_magnet:3d:mean_y                                                       float64
# raw_magnet:3d:mean_z                                                       float64
# raw_magnet:3d:std_x                                                        float64
# raw_magnet:3d:std_y                                                        float64
# raw_magnet:3d:std_z                                                        float64
# raw_magnet:3d:ro_xy                                                        float64
# raw_magnet:3d:ro_xz                                                        float64
# raw_magnet:3d:ro_yz                                                        float64
# raw_magnet:avr_cosine_similarity_lag_range0                                float64
# raw_magnet:avr_cosine_similarity_lag_range1                                float64
# raw_magnet:avr_cosine_similarity_lag_range2                                float64
# raw_magnet:avr_cosine_similarity_lag_range3                                float64
# raw_magnet:avr_cosine_similarity_lag_range4                                float64
# watch_acceleration:magnitude_stats:mean                                    float64
# watch_acceleration:magnitude_stats:std                                     float64
# watch_acceleration:magnitude_stats:moment3                                 float64
# watch_acceleration:magnitude_stats:moment4                                 float64
# watch_acceleration:magnitude_stats:percentile25                            float64
# watch_acceleration:magnitude_stats:percentile50                            float64
# watch_acceleration:magnitude_stats:percentile75                            float64
# watch_acceleration:magnitude_stats:value_entropy                           float64
# watch_acceleration:magnitude_stats:time_entropy                            float64
# watch_acceleration:magnitude_spectrum:log_energy_band0                     float64
# watch_acceleration:magnitude_spectrum:log_energy_band1                     float64
# watch_acceleration:magnitude_spectrum:log_energy_band2                     float64
# watch_acceleration:magnitude_spectrum:log_energy_band3                     float64
# watch_acceleration:magnitude_spectrum:log_energy_band4                     float64
# watch_acceleration:magnitude_spectrum:spectral_entropy                     float64
# watch_acceleration:magnitude_autocorrelation:period                        float64
# watch_acceleration:magnitude_autocorrelation:normalized_ac                 float64
# watch_acceleration:3d:mean_x                                               float64
# watch_acceleration:3d:mean_y                                               float64
# watch_acceleration:3d:mean_z                                               float64
# watch_acceleration:3d:std_x                                                float64
# watch_acceleration:3d:std_y                                                float64
# watch_acceleration:3d:std_z                                                float64
# watch_acceleration:3d:ro_xy                                                float64
# watch_acceleration:3d:ro_xz                                                float64
# watch_acceleration:3d:ro_yz                                                float64
# watch_acceleration:spectrum:x_log_energy_band0                             float64
# watch_acceleration:spectrum:x_log_energy_band1                             float64
# watch_acceleration:spectrum:x_log_energy_band2                             float64
# watch_acceleration:spectrum:x_log_energy_band3                             float64
# watch_acceleration:spectrum:x_log_energy_band4                             float64
# watch_acceleration:spectrum:y_log_energy_band0                             float64
# watch_acceleration:spectrum:y_log_energy_band1                             float64
# watch_acceleration:spectrum:y_log_energy_band2                             float64
# watch_acceleration:spectrum:y_log_energy_band3                             float64
# watch_acceleration:spectrum:y_log_energy_band4                             float64
# watch_acceleration:spectrum:z_log_energy_band0                             float64
# watch_acceleration:spectrum:z_log_energy_band1                             float64
# watch_acceleration:spectrum:z_log_energy_band2                             float64
# watch_acceleration:spectrum:z_log_energy_band3                             float64
# watch_acceleration:spectrum:z_log_energy_band4                             float64
# watch_acceleration:relative_directions:avr_cosine_similarity_lag_range0    float64
# watch_acceleration:relative_directions:avr_cosine_similarity_lag_range1    float64
# watch_acceleration:relative_directions:avr_cosine_similarity_lag_range2    float64
# watch_acceleration:relative_directions:avr_cosine_similarity_lag_range3    float64
# watch_acceleration:relative_directions:avr_cosine_similarity_lag_range4    float64
# watch_heading:mean_cos                                                     float64
# watch_heading:std_cos                                                      float64
# watch_heading:mom3_cos                                                     float64
# watch_heading:mom4_cos                                                     float64
# watch_heading:mean_sin                                                     float64
# watch_heading:std_sin                                                      float64
# watch_heading:mom3_sin                                                     float64
# watch_heading:mom4_sin                                                     float64
# watch_heading:entropy_8bins                                                float64
# location:num_valid_updates                                                 float64
# location:log_latitude_range                                                float64
# location:log_longitude_range                                               float64
# location:min_altitude                                                      float64
# location:max_altitude                                                      float64
# location:min_speed                                                         float64
# location:max_speed                                                         float64
# location:best_horizontal_accuracy                                          float64
# location:best_vertical_accuracy                                            float64
# location:diameter                                                          float64
# location:log_diameter                                                      float64
# location_quick_features:std_lat                                            float64
# location_quick_features:std_long                                           float64
# location_quick_features:lat_change                                         float64
# location_quick_features:long_change                                        float64
# location_quick_features:mean_abs_lat_deriv                                 float64
# location_quick_features:mean_abs_long_deriv                                float64
# audio_naive:mfcc0:mean                                                     float64
# audio_naive:mfcc1:mean                                                     float64
# audio_naive:mfcc2:mean                                                     float64
# audio_naive:mfcc3:mean                                                     float64
# audio_naive:mfcc4:mean                                                     float64
# audio_naive:mfcc5:mean                                                     float64
# audio_naive:mfcc6:mean                                                     float64
# audio_naive:mfcc7:mean                                                     float64
# audio_naive:mfcc8:mean                                                     float64
# audio_naive:mfcc9:mean                                                     float64
# audio_naive:mfcc10:mean                                                    float64
# audio_naive:mfcc11:mean                                                    float64
# audio_naive:mfcc12:mean                                                    float64
# audio_naive:mfcc0:std                                                      float64
# audio_naive:mfcc1:std                                                      float64
# audio_naive:mfcc2:std                                                      float64
# audio_naive:mfcc3:std                                                      float64
# audio_naive:mfcc4:std                                                      float64
# audio_naive:mfcc5:std                                                      float64
# audio_naive:mfcc6:std                                                      float64
# audio_naive:mfcc7:std                                                      float64
# audio_naive:mfcc8:std                                                      float64
# audio_naive:mfcc9:std                                                      float64
# audio_naive:mfcc10:std                                                     float64
# audio_naive:mfcc11:std                                                     float64
# audio_naive:mfcc12:std                                                     float64
# audio_properties:max_abs_value                                             float64
# audio_properties:normalization_multiplier                                  float64
# discrete:app_state:is_active                                               float64
# discrete:app_state:is_inactive                                             float64
# discrete:app_state:is_background                                           float64
# discrete:app_state:missing                                                 float64
# discrete:battery_plugged:is_ac                                             float64
# discrete:battery_plugged:is_usb                                            float64
# discrete:battery_plugged:is_wireless                                       float64
# discrete:battery_plugged:missing                                           float64
# discrete:battery_state:is_unknown                                          float64
# discrete:battery_state:is_unplugged                                        float64
# discrete:battery_state:is_not_charging                                     float64
# discrete:battery_state:is_discharging                                      float64
# discrete:battery_state:is_charging                                         float64
# discrete:battery_state:is_full                                             float64
# discrete:battery_state:missing                                             float64
# discrete:on_the_phone:is_False                                             float64
# discrete:on_the_phone:is_True                                              float64
# discrete:on_the_phone:missing                                              float64
# discrete:ringer_mode:is_normal                                             float64
# discrete:ringer_mode:is_silent_no_vibrate                                  float64
# discrete:ringer_mode:is_silent_with_vibrate                                float64
# discrete:ringer_mode:missing                                               float64
# discrete:wifi_status:is_not_reachable                                      float64
# discrete:wifi_status:is_reachable_via_wifi                                 float64
# discrete:wifi_status:is_reachable_via_wwan                                 float64
# discrete:wifi_status:missing                                               float64
# lf_measurements:light                                                      float64
# lf_measurements:pressure                                                   float64
# lf_measurements:proximity_cm                                               float64
# lf_measurements:proximity                                                  float64
# lf_measurements:relative_humidity                                          float64
# lf_measurements:battery_level                                              float64
# lf_measurements:screen_brightness                                          float64
# lf_measurements:temperature_ambient                                        float64
# discrete:time_of_day:between0and6                                          float64
# discrete:time_of_day:between3and9                                          float64
# discrete:time_of_day:between6and12                                         float64
# discrete:time_of_day:between9and15                                         float64
# discrete:time_of_day:between12and18                                        float64
# discrete:time_of_day:between15and21                                        float64
# discrete:time_of_day:between18and24                                        float64
# discrete:time_of_day:between21and3                                         float64
# timestamp                                                                  int64
# dtypes: float64(225), int64(1)
# memory usage: 653.5+ MB

# %%
features_df.head()
# Out:
#                                       raw_acc:magnitude_stats:mean  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                      0.996815
# 00EABED2-271D-49D8-B599-1D4A09240601                      0.996864
# 00EABED2-271D-49D8-B599-1D4A09240601                      0.996825
# 00EABED2-271D-49D8-B599-1D4A09240601                      0.996874
# 00EABED2-271D-49D8-B599-1D4A09240601                      0.997371
#
#                                       raw_acc:magnitude_stats:std  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                     0.003529
# 00EABED2-271D-49D8-B599-1D4A09240601                     0.004172
# 00EABED2-271D-49D8-B599-1D4A09240601                     0.003667
# 00EABED2-271D-49D8-B599-1D4A09240601                     0.003541
# 00EABED2-271D-49D8-B599-1D4A09240601                     0.037653
#
#                                       raw_acc:magnitude_stats:moment3  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                        -0.002786
# 00EABED2-271D-49D8-B599-1D4A09240601                        -0.003110
# 00EABED2-271D-49D8-B599-1D4A09240601                         0.003094
# 00EABED2-271D-49D8-B599-1D4A09240601                         0.000626
# 00EABED2-271D-49D8-B599-1D4A09240601                         0.043389
#
#                                       raw_acc:magnitude_stats:moment4  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                         0.006496
# 00EABED2-271D-49D8-B599-1D4A09240601                         0.007050
# 00EABED2-271D-49D8-B599-1D4A09240601                         0.006076
# 00EABED2-271D-49D8-B599-1D4A09240601                         0.006059
# 00EABED2-271D-49D8-B599-1D4A09240601                         0.102332
#
#                                       raw_acc:magnitude_stats:percentile25  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.995203
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.994957
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.994797
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.995050
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.995548
#
#                                       raw_acc:magnitude_stats:percentile50  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.996825
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.996981
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.996614
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.996907
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.996860
#
#                                       raw_acc:magnitude_stats:percentile75  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.998502
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.998766
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.998704
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.998690
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.998205
#
#                                       raw_acc:magnitude_stats:value_entropy  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                               1.748756
# 00EABED2-271D-49D8-B599-1D4A09240601                               1.935573
# 00EABED2-271D-49D8-B599-1D4A09240601                               2.031780
# 00EABED2-271D-49D8-B599-1D4A09240601                               1.865318
# 00EABED2-271D-49D8-B599-1D4A09240601                               0.460806
#
#                                       raw_acc:magnitude_stats:time_entropy  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                              6.684605
# 00EABED2-271D-49D8-B599-1D4A09240601                              6.684603
# 00EABED2-271D-49D8-B599-1D4A09240601                              6.684605
# 00EABED2-271D-49D8-B599-1D4A09240601                              6.684605
# 00EABED2-271D-49D8-B599-1D4A09240601                              6.683904
#
#                                       raw_acc:magnitude_spectrum:log_energy_band0  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                                     5.043970
# 00EABED2-271D-49D8-B599-1D4A09240601                                     5.043367
# 00EABED2-271D-49D8-B599-1D4A09240601                                     5.043599
# 00EABED2-271D-49D8-B599-1D4A09240601                                     5.043263
# 00EABED2-271D-49D8-B599-1D4A09240601                                     5.042779
#
#                                       ...  \
# uuid                                  ...
# 00EABED2-271D-49D8-B599-1D4A09240601  ...
# 00EABED2-271D-49D8-B599-1D4A09240601  ...
# 00EABED2-271D-49D8-B599-1D4A09240601  ...
# 00EABED2-271D-49D8-B599-1D4A09240601  ...
# 00EABED2-271D-49D8-B599-1D4A09240601  ...
#
#                                       lf_measurements:temperature_ambient  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                                  NaN
# 00EABED2-271D-49D8-B599-1D4A09240601                                  NaN
# 00EABED2-271D-49D8-B599-1D4A09240601                                  NaN
# 00EABED2-271D-49D8-B599-1D4A09240601                                  NaN
# 00EABED2-271D-49D8-B599-1D4A09240601                                  NaN
#
#                                       discrete:time_of_day:between0and6  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                                0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                0.0
#
#                                       discrete:time_of_day:between3and9  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                                0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                0.0
#
#                                       discrete:time_of_day:between6and12  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                                 0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                 0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                 0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                 0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                 0.0
#
#                                       discrete:time_of_day:between9and15  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                                 1.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                 1.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                 1.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                 1.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                 1.0
#
#                                       discrete:time_of_day:between12and18  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                                  1.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  1.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  1.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  1.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  1.0
#
#                                       discrete:time_of_day:between15and21  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
#
#                                       discrete:time_of_day:between18and24  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
#
#                                       discrete:time_of_day:between21and3  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                                 0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                 0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                 0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                 0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                 0.0
#
#                                        timestamp
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601  1444079161
# 00EABED2-271D-49D8-B599-1D4A09240601  1444079221
# 00EABED2-271D-49D8-B599-1D4A09240601  1444079281
# 00EABED2-271D-49D8-B599-1D4A09240601  1444079341
# 00EABED2-271D-49D8-B599-1D4A09240601  1444079431
#
# [5 rows x 226 columns]

# %%
label_df.head()
# Out:
#                                       label:LYING_DOWN  label:SITTING  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601               0.0            1.0
# 00EABED2-271D-49D8-B599-1D4A09240601               0.0            1.0
# 00EABED2-271D-49D8-B599-1D4A09240601               0.0            1.0
# 00EABED2-271D-49D8-B599-1D4A09240601               0.0            1.0
# 00EABED2-271D-49D8-B599-1D4A09240601               0.0            1.0
#
#                                       label:OR_standing  label:FIX_walking  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                0.0                0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                0.0                0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                0.0                0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                0.0                0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                0.0                0.0
#
#                                       label:FIX_running  label:BICYCLING  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                NaN              NaN
# 00EABED2-271D-49D8-B599-1D4A09240601                NaN              NaN
# 00EABED2-271D-49D8-B599-1D4A09240601                NaN              NaN
# 00EABED2-271D-49D8-B599-1D4A09240601                NaN              NaN
# 00EABED2-271D-49D8-B599-1D4A09240601                NaN              NaN
#
#                                        timestamp
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601  1444079161
# 00EABED2-271D-49D8-B599-1D4A09240601  1444079221
# 00EABED2-271D-49D8-B599-1D4A09240601  1444079281
# 00EABED2-271D-49D8-B599-1D4A09240601  1444079341
# 00EABED2-271D-49D8-B599-1D4A09240601  1444079431

# %%
label_df.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 377346 entries, 00EABED2-271D-49D8-B599-1D4A09240601 to FDAA70A1-42A3-4E3F-9AE3-3FDA412E03BF
# Data columns (total 7 columns):
# label:LYING_DOWN     303723 non-null float64
# label:SITTING        306594 non-null float64
# label:OR_standing    306594 non-null float64
# label:FIX_walking    306594 non-null float64
# label:FIX_running    140870 non-null float64
# label:BICYCLING      135183 non-null float64
# timestamp            377346 non-null int64
# dtypes: float64(6), int64(1)
# memory usage: 23.0+ MB

# %% [markdown]
# ### Create the dataset

# %%
data = pd.merge(features_df, label_df,
                how='left',
                left_on=['uuid','timestamp'], right_on = ['uuid','timestamp'])

# %%
data.head()
# Out:
#                                       raw_acc:magnitude_stats:mean  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                      0.996815
# 00EABED2-271D-49D8-B599-1D4A09240601                      0.996864
# 00EABED2-271D-49D8-B599-1D4A09240601                      0.996825
# 00EABED2-271D-49D8-B599-1D4A09240601                      0.996874
# 00EABED2-271D-49D8-B599-1D4A09240601                      0.997371
#
#                                       raw_acc:magnitude_stats:std  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                     0.003529
# 00EABED2-271D-49D8-B599-1D4A09240601                     0.004172
# 00EABED2-271D-49D8-B599-1D4A09240601                     0.003667
# 00EABED2-271D-49D8-B599-1D4A09240601                     0.003541
# 00EABED2-271D-49D8-B599-1D4A09240601                     0.037653
#
#                                       raw_acc:magnitude_stats:moment3  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                        -0.002786
# 00EABED2-271D-49D8-B599-1D4A09240601                        -0.003110
# 00EABED2-271D-49D8-B599-1D4A09240601                         0.003094
# 00EABED2-271D-49D8-B599-1D4A09240601                         0.000626
# 00EABED2-271D-49D8-B599-1D4A09240601                         0.043389
#
#                                       raw_acc:magnitude_stats:moment4  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                         0.006496
# 00EABED2-271D-49D8-B599-1D4A09240601                         0.007050
# 00EABED2-271D-49D8-B599-1D4A09240601                         0.006076
# 00EABED2-271D-49D8-B599-1D4A09240601                         0.006059
# 00EABED2-271D-49D8-B599-1D4A09240601                         0.102332
#
#                                       raw_acc:magnitude_stats:percentile25  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.995203
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.994957
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.994797
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.995050
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.995548
#
#                                       raw_acc:magnitude_stats:percentile50  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.996825
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.996981
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.996614
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.996907
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.996860
#
#                                       raw_acc:magnitude_stats:percentile75  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.998502
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.998766
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.998704
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.998690
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.998205
#
#                                       raw_acc:magnitude_stats:value_entropy  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                               1.748756
# 00EABED2-271D-49D8-B599-1D4A09240601                               1.935573
# 00EABED2-271D-49D8-B599-1D4A09240601                               2.031780
# 00EABED2-271D-49D8-B599-1D4A09240601                               1.865318
# 00EABED2-271D-49D8-B599-1D4A09240601                               0.460806
#
#                                       raw_acc:magnitude_stats:time_entropy  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                              6.684605
# 00EABED2-271D-49D8-B599-1D4A09240601                              6.684603
# 00EABED2-271D-49D8-B599-1D4A09240601                              6.684605
# 00EABED2-271D-49D8-B599-1D4A09240601                              6.684605
# 00EABED2-271D-49D8-B599-1D4A09240601                              6.683904
#
#                                       raw_acc:magnitude_spectrum:log_energy_band0  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                                     5.043970
# 00EABED2-271D-49D8-B599-1D4A09240601                                     5.043367
# 00EABED2-271D-49D8-B599-1D4A09240601                                     5.043599
# 00EABED2-271D-49D8-B599-1D4A09240601                                     5.043263
# 00EABED2-271D-49D8-B599-1D4A09240601                                     5.042779
#
#                                       ...  \
# uuid                                  ...
# 00EABED2-271D-49D8-B599-1D4A09240601  ...
# 00EABED2-271D-49D8-B599-1D4A09240601  ...
# 00EABED2-271D-49D8-B599-1D4A09240601  ...
# 00EABED2-271D-49D8-B599-1D4A09240601  ...
# 00EABED2-271D-49D8-B599-1D4A09240601  ...
#
#                                       discrete:time_of_day:between15and21  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
#
#                                       discrete:time_of_day:between18and24  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
#
#                                       discrete:time_of_day:between21and3  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                                 0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                 0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                 0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                 0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                 0.0
#
#                                        timestamp  label:LYING_DOWN  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601  1444079161               0.0
# 00EABED2-271D-49D8-B599-1D4A09240601  1444079221               0.0
# 00EABED2-271D-49D8-B599-1D4A09240601  1444079281               0.0
# 00EABED2-271D-49D8-B599-1D4A09240601  1444079341               0.0
# 00EABED2-271D-49D8-B599-1D4A09240601  1444079431               0.0
#
#                                       label:SITTING  label:OR_standing  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601            1.0                0.0
# 00EABED2-271D-49D8-B599-1D4A09240601            1.0                0.0
# 00EABED2-271D-49D8-B599-1D4A09240601            1.0                0.0
# 00EABED2-271D-49D8-B599-1D4A09240601            1.0                0.0
# 00EABED2-271D-49D8-B599-1D4A09240601            1.0                0.0
#
#                                       label:FIX_walking  label:FIX_running  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                0.0                NaN
# 00EABED2-271D-49D8-B599-1D4A09240601                0.0                NaN
# 00EABED2-271D-49D8-B599-1D4A09240601                0.0                NaN
# 00EABED2-271D-49D8-B599-1D4A09240601                0.0                NaN
# 00EABED2-271D-49D8-B599-1D4A09240601                0.0                NaN
#
#                                       label:BICYCLING
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601              NaN
# 00EABED2-271D-49D8-B599-1D4A09240601              NaN
# 00EABED2-271D-49D8-B599-1D4A09240601              NaN
# 00EABED2-271D-49D8-B599-1D4A09240601              NaN
# 00EABED2-271D-49D8-B599-1D4A09240601              NaN
#
# [5 rows x 232 columns]

# %%
# # Testing
# from itertools import combinations

# def is_mutual_exclusive(series_1, series_2):
#     return  series_1 & series_2

# for cols in combinations(data[main_label_names].columns, 2):
#     series_1 = data[cols[0]]
#     series_2 = data[cols[1]]
    
#     mask = is_mutual_exclusive(series_1, series_2)
    
#     if data[mask].shape[0] > 0:
#         raise ValueError("the lables contains unmutual exclusive rows")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#    1253         try:
# -> 1254             result = op(x, y)
#    1255         except TypeError:
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-8a4997aebc2c> in <module>
#       9     series_2 = data[cols[1]]
#      10
# ---> 11     mask = is_mutual_exclusive(series_1, series_2)
#      12
#      13     if data[mask].shape[0] > 0:
#
# <ipython-input-61-8a4997aebc2c> in is_mutual_exclusive(series_1, series_2)
#       3
#       4 def is_mutual_exclusive(series_1, series_2):
# ----> 5     return  series_1 & series_2
#       6
#       7 for cols in combinations(data[main_label_names].columns, 2):
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#    1319         #   integer dtypes.  Otherwise these are boolean ops
#    1320         filler = fill_int if is_self_int_dtype and is_other_int_dtype else fill_bool
# -> 1321         res_values = na_op(self.values, ovalues)
#    1322         unfilled = self._constructor(res_values, index=self.index, name=res_name)
#    1323         filled = filler(unfilled)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#    1260                 x = ensure_object(x)
#    1261                 y = ensure_object(y)
# -> 1262                 result = libops.vec_binop(x, y, op)
#    1263             else:
#    1264                 # let null fall thru
#
# pandas/_libs/ops.pyx in pandas._libs.ops.vec_binop()
#
# pandas/_libs/ops.pyx in pandas._libs.ops.vec_binop()
#
# TypeError: unsupported operand type(s) for &: 'float' and 'bool'

# %%
# Mapping between label name and a unique category number
def create_mapping_dict(main_activity_lables):
    main_activity_lables_mapping = dict()

    for category, label in enumerate(main_activity_lables):
        main_activity_lables_mapping[category] = label
        
    return main_activity_lables_mapping
    
def map_label_index_to_name(index, main_activity_lables_mapping):
    label_name = main_activity_lables_mapping[index]
    
    return label_name


main_activity_lables_mapping = create_mapping_dict(main_label_names)
data['label'] = np.argmax(data[main_label_names].values, axis=1)
data['label_name'] = data['label'].apply(map_label_index_to_name, main_activity_lables_mapping=main_activity_lables_mapping)

data.drop(main_label_names, inplace=True, axis=1)

# %%
data.head()
# Out:
#                                       raw_acc:magnitude_stats:mean  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                      0.996815
# 00EABED2-271D-49D8-B599-1D4A09240601                      0.996864
# 00EABED2-271D-49D8-B599-1D4A09240601                      0.996825
# 00EABED2-271D-49D8-B599-1D4A09240601                      0.996874
# 00EABED2-271D-49D8-B599-1D4A09240601                      0.997371
#
#                                       raw_acc:magnitude_stats:std  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                     0.003529
# 00EABED2-271D-49D8-B599-1D4A09240601                     0.004172
# 00EABED2-271D-49D8-B599-1D4A09240601                     0.003667
# 00EABED2-271D-49D8-B599-1D4A09240601                     0.003541
# 00EABED2-271D-49D8-B599-1D4A09240601                     0.037653
#
#                                       raw_acc:magnitude_stats:moment3  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                        -0.002786
# 00EABED2-271D-49D8-B599-1D4A09240601                        -0.003110
# 00EABED2-271D-49D8-B599-1D4A09240601                         0.003094
# 00EABED2-271D-49D8-B599-1D4A09240601                         0.000626
# 00EABED2-271D-49D8-B599-1D4A09240601                         0.043389
#
#                                       raw_acc:magnitude_stats:moment4  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                         0.006496
# 00EABED2-271D-49D8-B599-1D4A09240601                         0.007050
# 00EABED2-271D-49D8-B599-1D4A09240601                         0.006076
# 00EABED2-271D-49D8-B599-1D4A09240601                         0.006059
# 00EABED2-271D-49D8-B599-1D4A09240601                         0.102332
#
#                                       raw_acc:magnitude_stats:percentile25  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.995203
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.994957
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.994797
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.995050
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.995548
#
#                                       raw_acc:magnitude_stats:percentile50  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.996825
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.996981
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.996614
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.996907
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.996860
#
#                                       raw_acc:magnitude_stats:percentile75  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.998502
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.998766
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.998704
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.998690
# 00EABED2-271D-49D8-B599-1D4A09240601                              0.998205
#
#                                       raw_acc:magnitude_stats:value_entropy  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                               1.748756
# 00EABED2-271D-49D8-B599-1D4A09240601                               1.935573
# 00EABED2-271D-49D8-B599-1D4A09240601                               2.031780
# 00EABED2-271D-49D8-B599-1D4A09240601                               1.865318
# 00EABED2-271D-49D8-B599-1D4A09240601                               0.460806
#
#                                       raw_acc:magnitude_stats:time_entropy  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                              6.684605
# 00EABED2-271D-49D8-B599-1D4A09240601                              6.684603
# 00EABED2-271D-49D8-B599-1D4A09240601                              6.684605
# 00EABED2-271D-49D8-B599-1D4A09240601                              6.684605
# 00EABED2-271D-49D8-B599-1D4A09240601                              6.683904
#
#                                       raw_acc:magnitude_spectrum:log_energy_band0  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                                     5.043970
# 00EABED2-271D-49D8-B599-1D4A09240601                                     5.043367
# 00EABED2-271D-49D8-B599-1D4A09240601                                     5.043599
# 00EABED2-271D-49D8-B599-1D4A09240601                                     5.043263
# 00EABED2-271D-49D8-B599-1D4A09240601                                     5.042779
#
#                                       ...  discrete:time_of_day:between3and9  \
# uuid                                  ...
# 00EABED2-271D-49D8-B599-1D4A09240601  ...                                0.0
# 00EABED2-271D-49D8-B599-1D4A09240601  ...                                0.0
# 00EABED2-271D-49D8-B599-1D4A09240601  ...                                0.0
# 00EABED2-271D-49D8-B599-1D4A09240601  ...                                0.0
# 00EABED2-271D-49D8-B599-1D4A09240601  ...                                0.0
#
#                                       discrete:time_of_day:between6and12  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                                 0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                 0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                 0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                 0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                 0.0
#
#                                       discrete:time_of_day:between9and15  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                                 1.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                 1.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                 1.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                 1.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                 1.0
#
#                                       discrete:time_of_day:between12and18  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                                  1.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  1.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  1.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  1.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  1.0
#
#                                       discrete:time_of_day:between15and21  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
#
#                                       discrete:time_of_day:between18and24  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                  0.0
#
#                                       discrete:time_of_day:between21and3  \
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601                                 0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                 0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                 0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                 0.0
# 00EABED2-271D-49D8-B599-1D4A09240601                                 0.0
#
#                                        timestamp  label         label_name
# uuid
# 00EABED2-271D-49D8-B599-1D4A09240601  1444079161      4  label:FIX_running
# 00EABED2-271D-49D8-B599-1D4A09240601  1444079221      4  label:FIX_running
# 00EABED2-271D-49D8-B599-1D4A09240601  1444079281      4  label:FIX_running
# 00EABED2-271D-49D8-B599-1D4A09240601  1444079341      4  label:FIX_running
# 00EABED2-271D-49D8-B599-1D4A09240601  1444079431      4  label:FIX_running
#
# [5 rows x 228 columns]

# %%
data.shape
# Out:
# (377346, 228)

# %%
data.describe()
# Out:
#        raw_acc:magnitude_stats:mean  raw_acc:magnitude_stats:std  \
# count                 377056.000000                377056.000000
# mean                       1.002223                     0.038832
# std                        0.079623                     0.096109
# min                        0.018148                     0.000030
# 25%                        0.992556                     0.001709
# 50%                        1.001258                     0.003265
# 75%                        1.012745                     0.021366
# max                        3.185837                     1.936343
#
#        raw_acc:magnitude_stats:moment3  raw_acc:magnitude_stats:moment4  \
# count                    377056.000000                    377056.000000
# mean                          0.037772                         0.072804
# std                           0.113198                         0.170481
# min                          -0.493806                         0.000039
# 25%                          -0.000785                         0.002328
# 50%                           0.000772                         0.005051
# 75%                           0.009864                         0.045333
# max                           2.472750                         3.360718
#
#        raw_acc:magnitude_stats:percentile25  \
# count                         377056.000000
# mean                               0.983165
# std                                0.082960
# min                                0.015845
# 25%                                0.982671
# 50%                                0.995300
# 75%                                1.003679
# max                                1.942718
#
#        raw_acc:magnitude_stats:percentile50  \
# count                         377056.000000
# mean                               0.998471
# std                                0.076687
# min                                0.017998
# 25%                                0.991248
# 50%                                1.000116
# 75%                                1.009232
# max                                2.636697
#
#        raw_acc:magnitude_stats:percentile75  \
# count                         377056.000000
# mean                               1.016691
# std                                0.104874
# min                                0.020365
# 25%                                0.994859
# 50%                                1.003813
# 75%                                1.019163
# max                                3.958338
#
#        raw_acc:magnitude_stats:value_entropy  \
# count                          377056.000000
# mean                                2.045331
# std                                 0.616899
# min                                 0.009605
# 25%                                 1.671571
# 50%                                 2.296398
# 75%                                 2.523618
# max                                 2.971272
#
#        raw_acc:magnitude_stats:time_entropy  \
# count                         377056.000000
# mean                               6.680278
# std                                0.021246
# min                                5.460637
# 25%                                6.684369
# 50%                                6.684606
# 75%                                6.684610
# max                                6.684612
#
#        raw_acc:magnitude_spectrum:log_energy_band0  ...  \
# count                                377056.000000  ...
# mean                                      5.039597  ...
# std                                       0.025809  ...
# min                                       4.338109  ...
# 25%                                       5.042891  ...
# 50%                                       5.043350  ...
# 75%                                       5.043574  ...
# max                                       6.489025  ...
#
#        discrete:time_of_day:between0and6  discrete:time_of_day:between3and9  \
# count                      377346.000000                      377346.000000
# mean                            0.218865                           0.206169
# std                             0.413478                           0.404554
# min                             0.000000                           0.000000
# 25%                             0.000000                           0.000000
# 50%                             0.000000                           0.000000
# 75%                             0.000000                           0.000000
# max                             1.000000                           1.000000
#
#        discrete:time_of_day:between6and12  discrete:time_of_day:between9and15  \
# count                       377346.000000                       377346.000000
# mean                             0.229066                            0.267147
# std                              0.420232                            0.442471
# min                              0.000000                            0.000000
# 25%                              0.000000                            0.000000
# 50%                              0.000000                            0.000000
# 75%                              0.000000                            1.000000
# max                              1.000000                            1.000000
#
#        discrete:time_of_day:between12and18  \
# count                        377346.000000
# mean                              0.285608
# std                               0.451704
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               1.000000
# max                               1.000000
#
#        discrete:time_of_day:between15and21  \
# count                        377346.000000
# mean                              0.285624
# std                               0.451712
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               1.000000
# max                               1.000000
#
#        discrete:time_of_day:between18and24  \
# count                        377346.000000
# mean                              0.266461
# std                               0.442109
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               1.000000
# max                               1.000000
#
#        discrete:time_of_day:between21and3     timestamp          label
# count                       377346.000000  3.773460e+05  377346.000000
# mean                             0.276425  1.445839e+09       3.064241
# std                              0.447230  5.907009e+06       1.950021
# min                              0.000000  1.433537e+09       0.000000
# 25%                              0.000000  1.441438e+09       1.000000
# 50%                              0.000000  1.444974e+09       4.000000
# 75%                              1.000000  1.448696e+09       4.000000
# max                              1.000000  1.464899e+09       5.000000
#
# [8 rows x 227 columns]

# %%
data.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 377346 entries, 00EABED2-271D-49D8-B599-1D4A09240601 to FDAA70A1-42A3-4E3F-9AE3-3FDA412E03BF
# Data columns (total 228 columns):
# raw_acc:magnitude_stats:mean                                               377056 non-null float64
# raw_acc:magnitude_stats:std                                                377056 non-null float64
# raw_acc:magnitude_stats:moment3                                            377056 non-null float64
# raw_acc:magnitude_stats:moment4                                            377056 non-null float64
# raw_acc:magnitude_stats:percentile25                                       377056 non-null float64
# raw_acc:magnitude_stats:percentile50                                       377056 non-null float64
# raw_acc:magnitude_stats:percentile75                                       377056 non-null float64
# raw_acc:magnitude_stats:value_entropy                                      377056 non-null float64
# raw_acc:magnitude_stats:time_entropy                                       377056 non-null float64
# raw_acc:magnitude_spectrum:log_energy_band0                                377056 non-null float64
# raw_acc:magnitude_spectrum:log_energy_band1                                377056 non-null float64
# raw_acc:magnitude_spectrum:log_energy_band2                                377056 non-null float64
# raw_acc:magnitude_spectrum:log_energy_band3                                377056 non-null float64
# raw_acc:magnitude_spectrum:log_energy_band4                                377056 non-null float64
# raw_acc:magnitude_spectrum:spectral_entropy                                377056 non-null float64
# raw_acc:magnitude_autocorrelation:period                                   377056 non-null float64
# raw_acc:magnitude_autocorrelation:normalized_ac                            377056 non-null float64
# raw_acc:3d:mean_x                                                          377056 non-null float64
# raw_acc:3d:mean_y                                                          377056 non-null float64
# raw_acc:3d:mean_z                                                          377056 non-null float64
# raw_acc:3d:std_x                                                           377056 non-null float64
# raw_acc:3d:std_y                                                           377056 non-null float64
# raw_acc:3d:std_z                                                           377056 non-null float64
# raw_acc:3d:ro_xy                                                           377056 non-null float64
# raw_acc:3d:ro_xz                                                           377056 non-null float64
# raw_acc:3d:ro_yz                                                           377056 non-null float64
# proc_gyro:magnitude_stats:mean                                             359912 non-null float64
# proc_gyro:magnitude_stats:std                                              359912 non-null float64
# proc_gyro:magnitude_stats:moment3                                          359912 non-null float64
# proc_gyro:magnitude_stats:moment4                                          359912 non-null float64
# proc_gyro:magnitude_stats:percentile25                                     359912 non-null float64
# proc_gyro:magnitude_stats:percentile50                                     359912 non-null float64
# proc_gyro:magnitude_stats:percentile75                                     359912 non-null float64
# proc_gyro:magnitude_stats:value_entropy                                    359912 non-null float64
# proc_gyro:magnitude_stats:time_entropy                                     359912 non-null float64
# proc_gyro:magnitude_spectrum:log_energy_band0                              359912 non-null float64
# proc_gyro:magnitude_spectrum:log_energy_band1                              359912 non-null float64
# proc_gyro:magnitude_spectrum:log_energy_band2                              359912 non-null float64
# proc_gyro:magnitude_spectrum:log_energy_band3                              359912 non-null float64
# proc_gyro:magnitude_spectrum:log_energy_band4                              359912 non-null float64
# proc_gyro:magnitude_spectrum:spectral_entropy                              359912 non-null float64
# proc_gyro:magnitude_autocorrelation:period                                 359912 non-null float64
# proc_gyro:magnitude_autocorrelation:normalized_ac                          359898 non-null float64
# proc_gyro:3d:mean_x                                                        359912 non-null float64
# proc_gyro:3d:mean_y                                                        359912 non-null float64
# proc_gyro:3d:mean_z                                                        359912 non-null float64
# proc_gyro:3d:std_x                                                         359912 non-null float64
# proc_gyro:3d:std_y                                                         359912 non-null float64
# proc_gyro:3d:std_z                                                         359912 non-null float64
# proc_gyro:3d:ro_xy                                                         358123 non-null float64
# proc_gyro:3d:ro_xz                                                         358114 non-null float64
# proc_gyro:3d:ro_yz                                                         358114 non-null float64
# raw_magnet:magnitude_stats:mean                                            346025 non-null float64
# raw_magnet:magnitude_stats:std                                             346025 non-null float64
# raw_magnet:magnitude_stats:moment3                                         346025 non-null float64
# raw_magnet:magnitude_stats:moment4                                         346025 non-null float64
# raw_magnet:magnitude_stats:percentile25                                    346025 non-null float64
# raw_magnet:magnitude_stats:percentile50                                    346025 non-null float64
# raw_magnet:magnitude_stats:percentile75                                    346025 non-null float64
# raw_magnet:magnitude_stats:value_entropy                                   346025 non-null float64
# raw_magnet:magnitude_stats:time_entropy                                    346025 non-null float64
# raw_magnet:magnitude_spectrum:log_energy_band0                             346025 non-null float64
# raw_magnet:magnitude_spectrum:log_energy_band1                             346025 non-null float64
# raw_magnet:magnitude_spectrum:log_energy_band2                             346025 non-null float64
# raw_magnet:magnitude_spectrum:log_energy_band3                             346025 non-null float64
# raw_magnet:magnitude_spectrum:log_energy_band4                             346025 non-null float64
# raw_magnet:magnitude_spectrum:spectral_entropy                             346025 non-null float64
# raw_magnet:magnitude_autocorrelation:period                                346025 non-null float64
# raw_magnet:magnitude_autocorrelation:normalized_ac                         346024 non-null float64
# raw_magnet:3d:mean_x                                                       346025 non-null float64
# raw_magnet:3d:mean_y                                                       346025 non-null float64
# raw_magnet:3d:mean_z                                                       346025 non-null float64
# raw_magnet:3d:std_x                                                        346025 non-null float64
# raw_magnet:3d:std_y                                                        346025 non-null float64
# raw_magnet:3d:std_z                                                        346025 non-null float64
# raw_magnet:3d:ro_xy                                                        345149 non-null float64
# raw_magnet:3d:ro_xz                                                        345575 non-null float64
# raw_magnet:3d:ro_yz                                                        345449 non-null float64
# raw_magnet:avr_cosine_similarity_lag_range0                                346025 non-null float64
# raw_magnet:avr_cosine_similarity_lag_range1                                346025 non-null float64
# raw_magnet:avr_cosine_similarity_lag_range2                                346025 non-null float64
# raw_magnet:avr_cosine_similarity_lag_range3                                346025 non-null float64
# raw_magnet:avr_cosine_similarity_lag_range4                                346025 non-null float64
# watch_acceleration:magnitude_stats:mean                                    244802 non-null float64
# watch_acceleration:magnitude_stats:std                                     244802 non-null float64
# watch_acceleration:magnitude_stats:moment3                                 244802 non-null float64
# watch_acceleration:magnitude_stats:moment4                                 244802 non-null float64
# watch_acceleration:magnitude_stats:percentile25                            244802 non-null float64
# watch_acceleration:magnitude_stats:percentile50                            244802 non-null float64
# watch_acceleration:magnitude_stats:percentile75                            244802 non-null float64
# watch_acceleration:magnitude_stats:value_entropy                           244802 non-null float64
# watch_acceleration:magnitude_stats:time_entropy                            244802 non-null float64
# watch_acceleration:magnitude_spectrum:log_energy_band0                     244802 non-null float64
# watch_acceleration:magnitude_spectrum:log_energy_band1                     244802 non-null float64
# watch_acceleration:magnitude_spectrum:log_energy_band2                     244802 non-null float64
# watch_acceleration:magnitude_spectrum:log_energy_band3                     244802 non-null float64
# watch_acceleration:magnitude_spectrum:log_energy_band4                     244802 non-null float64
# watch_acceleration:magnitude_spectrum:spectral_entropy                     244802 non-null float64
# watch_acceleration:magnitude_autocorrelation:period                        244802 non-null float64
# watch_acceleration:magnitude_autocorrelation:normalized_ac                 244802 non-null float64
# watch_acceleration:3d:mean_x                                               244802 non-null float64
# watch_acceleration:3d:mean_y                                               244802 non-null float64
# watch_acceleration:3d:mean_z                                               244802 non-null float64
# watch_acceleration:3d:std_x                                                244802 non-null float64
# watch_acceleration:3d:std_y                                                244802 non-null float64
# watch_acceleration:3d:std_z                                                244802 non-null float64
# watch_acceleration:3d:ro_xy                                                244802 non-null float64
# watch_acceleration:3d:ro_xz                                                244802 non-null float64
# watch_acceleration:3d:ro_yz                                                244802 non-null float64
# watch_acceleration:spectrum:x_log_energy_band0                             244802 non-null float64
# watch_acceleration:spectrum:x_log_energy_band1                             244802 non-null float64
# watch_acceleration:spectrum:x_log_energy_band2                             244802 non-null float64
# watch_acceleration:spectrum:x_log_energy_band3                             244802 non-null float64
# watch_acceleration:spectrum:x_log_energy_band4                             244802 non-null float64
# watch_acceleration:spectrum:y_log_energy_band0                             244802 non-null float64
# watch_acceleration:spectrum:y_log_energy_band1                             244802 non-null float64
# watch_acceleration:spectrum:y_log_energy_band2                             244802 non-null float64
# watch_acceleration:spectrum:y_log_energy_band3                             244802 non-null float64
# watch_acceleration:spectrum:y_log_energy_band4                             244802 non-null float64
# watch_acceleration:spectrum:z_log_energy_band0                             244802 non-null float64
# watch_acceleration:spectrum:z_log_energy_band1                             244802 non-null float64
# watch_acceleration:spectrum:z_log_energy_band2                             244802 non-null float64
# watch_acceleration:spectrum:z_log_energy_band3                             244802 non-null float64
# watch_acceleration:spectrum:z_log_energy_band4                             244802 non-null float64
# watch_acceleration:relative_directions:avr_cosine_similarity_lag_range0    244802 non-null float64
# watch_acceleration:relative_directions:avr_cosine_similarity_lag_range1    244802 non-null float64
# watch_acceleration:relative_directions:avr_cosine_similarity_lag_range2    244802 non-null float64
# watch_acceleration:relative_directions:avr_cosine_similarity_lag_range3    244802 non-null float64
# watch_acceleration:relative_directions:avr_cosine_similarity_lag_range4    244802 non-null float64
# watch_heading:mean_cos                                                     147415 non-null float64
# watch_heading:std_cos                                                      147415 non-null float64
# watch_heading:mom3_cos                                                     147415 non-null float64
# watch_heading:mom4_cos                                                     147415 non-null float64
# watch_heading:mean_sin                                                     147415 non-null float64
# watch_heading:std_sin                                                      147415 non-null float64
# watch_heading:mom3_sin                                                     147415 non-null float64
# watch_heading:mom4_sin                                                     147415 non-null float64
# watch_heading:entropy_8bins                                                147415 non-null float64
# location:num_valid_updates                                                 333934 non-null float64
# location:log_latitude_range                                                301999 non-null float64
# location:log_longitude_range                                               301999 non-null float64
# location:min_altitude                                                      217100 non-null float64
# location:max_altitude                                                      217100 non-null float64
# location:min_speed                                                         104529 non-null float64
# location:max_speed                                                         104529 non-null float64
# location:best_horizontal_accuracy                                          305338 non-null float64
# location:best_vertical_accuracy                                            217100 non-null float64
# location:diameter                                                          333934 non-null float64
# location:log_diameter                                                      333934 non-null float64
# location_quick_features:std_lat                                            320576 non-null float64
# location_quick_features:std_long                                           317601 non-null float64
# location_quick_features:lat_change                                         322288 non-null float64
# location_quick_features:long_change                                        322288 non-null float64
# location_quick_features:mean_abs_lat_deriv                                 318016 non-null float64
# location_quick_features:mean_abs_long_deriv                                317996 non-null float64
# audio_naive:mfcc0:mean                                                     367752 non-null float64
# audio_naive:mfcc1:mean                                                     367752 non-null float64
# audio_naive:mfcc2:mean                                                     367752 non-null float64
# audio_naive:mfcc3:mean                                                     367752 non-null float64
# audio_naive:mfcc4:mean                                                     367752 non-null float64
# audio_naive:mfcc5:mean                                                     367752 non-null float64
# audio_naive:mfcc6:mean                                                     367752 non-null float64
# audio_naive:mfcc7:mean                                                     367752 non-null float64
# audio_naive:mfcc8:mean                                                     367752 non-null float64
# audio_naive:mfcc9:mean                                                     367752 non-null float64
# audio_naive:mfcc10:mean                                                    367752 non-null float64
# audio_naive:mfcc11:mean                                                    367752 non-null float64
# audio_naive:mfcc12:mean                                                    367752 non-null float64
# audio_naive:mfcc0:std                                                      367752 non-null float64
# audio_naive:mfcc1:std                                                      367752 non-null float64
# audio_naive:mfcc2:std                                                      367752 non-null float64
# audio_naive:mfcc3:std                                                      367752 non-null float64
# audio_naive:mfcc4:std                                                      367752 non-null float64
# audio_naive:mfcc5:std                                                      367752 non-null float64
# audio_naive:mfcc6:std                                                      367752 non-null float64
# audio_naive:mfcc7:std                                                      367752 non-null float64
# audio_naive:mfcc8:std                                                      367752 non-null float64
# audio_naive:mfcc9:std                                                      367752 non-null float64
# audio_naive:mfcc10:std                                                     367752 non-null float64
# audio_naive:mfcc11:std                                                     367752 non-null float64
# audio_naive:mfcc12:std                                                     367752 non-null float64
# audio_properties:max_abs_value                                             369953 non-null float64
# audio_properties:normalization_multiplier                                  369953 non-null float64
# discrete:app_state:is_active                                               377346 non-null float64
# discrete:app_state:is_inactive                                             377346 non-null float64
# discrete:app_state:is_background                                           377346 non-null float64
# discrete:app_state:missing                                                 377346 non-null float64
# discrete:battery_plugged:is_ac                                             377346 non-null float64
# discrete:battery_plugged:is_usb                                            377346 non-null float64
# discrete:battery_plugged:is_wireless                                       377346 non-null float64
# discrete:battery_plugged:missing                                           377346 non-null float64
# discrete:battery_state:is_unknown                                          377346 non-null float64
# discrete:battery_state:is_unplugged                                        377346 non-null float64
# discrete:battery_state:is_not_charging                                     377346 non-null float64
# discrete:battery_state:is_discharging                                      377346 non-null float64
# discrete:battery_state:is_charging                                         377346 non-null float64
# discrete:battery_state:is_full                                             377346 non-null float64
# discrete:battery_state:missing                                             377346 non-null float64
# discrete:on_the_phone:is_False                                             377346 non-null float64
# discrete:on_the_phone:is_True                                              377346 non-null float64
# discrete:on_the_phone:missing                                              377346 non-null float64
# discrete:ringer_mode:is_normal                                             377346 non-null float64
# discrete:ringer_mode:is_silent_no_vibrate                                  377346 non-null float64
# discrete:ringer_mode:is_silent_with_vibrate                                377346 non-null float64
# discrete:ringer_mode:missing                                               377346 non-null float64
# discrete:wifi_status:is_not_reachable                                      377346 non-null float64
# discrete:wifi_status:is_reachable_via_wifi                                 377346 non-null float64
# discrete:wifi_status:is_reachable_via_wwan                                 377346 non-null float64
# discrete:wifi_status:missing                                               377346 non-null float64
# lf_measurements:light                                                      147032 non-null float64
# lf_measurements:pressure                                                   107195 non-null float64
# lf_measurements:proximity_cm                                               148620 non-null float64
# lf_measurements:proximity                                                  220949 non-null float64
# lf_measurements:relative_humidity                                          25939 non-null float64
# lf_measurements:battery_level                                              377027 non-null float64
# lf_measurements:screen_brightness                                          220949 non-null float64
# lf_measurements:temperature_ambient                                        26450 non-null float64
# discrete:time_of_day:between0and6                                          377346 non-null float64
# discrete:time_of_day:between3and9                                          377346 non-null float64
# discrete:time_of_day:between6and12                                         377346 non-null float64
# discrete:time_of_day:between9and15                                         377346 non-null float64
# discrete:time_of_day:between12and18                                        377346 non-null float64
# discrete:time_of_day:between15and21                                        377346 non-null float64
# discrete:time_of_day:between18and24                                        377346 non-null float64
# discrete:time_of_day:between21and3                                         377346 non-null float64
# timestamp                                                                  377346 non-null int64
# label                                                                      377346 non-null int64
# label_name                                                                 377346 non-null object
# dtypes: float64(225), int64(2), object(1)
# memory usage: 659.3+ MB

# %%
data.to_csv(DATA_PATH / "dataset.csv")
